# %% [markdown]
# # 🧮 Numbers in Python (int vs float)
#
# In Python, numbers are used for math!
#
# ✅ Integers (int)
#
# Integers are whole numbers (no decimals):
#
# 1, 2, 3, 100, -5

# %% [markdown]
# Example:

# %%
print(2 * 1)

# %% [markdown]
# ✅ Floats (float)
#
# Floats are decimal numbers:
#
# 1.0, 1.1, 1.25, 0.3

# %% [markdown]
# Example:

# %%
print(2.0 - 1)

# %% [markdown]
# Division usually gives a float:

# %%
print(5 / 1)

# %% [markdown]
# # ⚠️ IMPORTANT: You can’t add a String + Number

# %% [markdown]
# This will cause an error ❌:

# %%
print("5" + 10)

# %% [markdown]
# But this is totally fine ✅:

# %%
print(5 + 10)
