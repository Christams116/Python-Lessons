# %% [markdown]
# ## ⌨️ Python Homework: Talking to Your Computer
# Instructions: Copy and paste these cells. Remember, when you run these, Python will pause and wait for you to type your answer in the box!
#
# # 🛑 Task 1: The Great Pause
# The input() function tells Python to stop and wait until you press Enter. Your Goal: Create a variable called food. Use input() to ask "What is your favorite snack?". Then, print the variable to see it stored your answer!

# %%
# Ask the question here:
food = input("What is your favorite snack? ")

# Print the answer here:

# %% [markdown]
# ## 🎨 Task 2: Building a Greeting
# You can use the answer from input() to build a full sentence. Your Goal: Ask the user for their favorite color. Then, print a sentence like "Wow, blue is a great color!" (but use the variable so it works for any color).

# %%
# 1. Ask for a color:
color = 

# 2. Print the sentence using + to join the strings:
print("Wow, " + color + " is a great color!")

# %% [markdown]
# ## 🕵️ Task 3: The "String" Secret
# This is a super important rule: input() always gives you a string (text), even if you type a number! Your Goal: Run the code below. Type in a number. Look at the result—does it say str (string) or int (integer)?

# %%
# Run this and type a number:
age = input("How many years old are you? ")

# This tells us the 'type' of the data:
print(type(age))

# %% [markdown]
# ## 💬 Task 4: Double Questions
# You can ask more than one question in a row. Your Goal: Write a program that asks for a city and then asks for a country. Print them both out together.

# %%
# Ask for the city:

# Ask for the country:

# Print them together:

# %% [markdown]
# ## 🧙 Task 5: The Math Trap (Challenge)
# Since input() gives you a string, math might act funny. Your Goal: Ask the user for a "Lucky Number." Then, try to multiply that variable by 3. If you type 7, do you get 21 or 777?

# %%
# 1. Ask for a lucky number:
lucky = 

# 2. Multiply it by 3 and print the result:
