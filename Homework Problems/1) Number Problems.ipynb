# %% [markdown]
# # 📝 Python Homework: Numbers & Math
# Instructions: Copy each cell below into your own Python notebook. Read the instructions and write the code to find the answers!
#
# ## 🌟 Task 1: Whole Numbers (Integers)
# Integers are whole numbers with no decimals. Your Goal: In the cell below, use Python to multiply 10 times 5.

# %%
# Type your code for 10 times 5 below and run it!

# %% [markdown]
# ## 🍕 Task 2: Decimal Numbers (Floats)
# Floats have a decimal point. Imagine you have $5.50 and you spend $2.00. Your Goal: Subtract 2.0 from 5.5 to see how much is left.

# %%
# Type your code for 5.5 minus 2.0 below:

# %% [markdown]
# ## ➗ Task 3: The Division Trick
# Remember, in Python, dividing usually turns a number into a float (it adds a .0 at the end). Your Goal: Divide 10 by 2. Does the answer look like 5 or 5.0?

# %%
# Use the / symbol to divide 10 by 2:

# %% [markdown]
# ## 🚫 Task 4: The Mystery Error
# Python gets confused if we try to add words (Strings) and numbers together. Your Goal: Run the code below. It will give you a big red Error. Read the error, then fix it by removing the quotation marks around the number 7.

# %%
# FIX THIS CODE:
print("7" + 3)

# %% [markdown]
# ## 🎨 Task 5: Mega Math Challenge
# Let's combine everything! Your Goal: Create a math problem that uses one integer (like 10) and one float (like 0.5). You can add, subtract, or multiply them!

# %%
# Write your own math problem using an int and a float:
