# %% [markdown]
# # 🧵 Python Homework: String Magic
# Instructions: Copy and paste these cells. Follow the directions to see how Python treats words and sentences!
#
# ## 🧱 Task 1: Building a Sentence
# In Python, a string is text inside "double quotes" or 'single quotes'. You can use the + symbol to glue two strings together—this is called concatenation. Your Goal: Create a string of your first name and a string of your last name. Use + to join them together with a space in the middle.

# %%
# Glue your name together here! 
# Hint: Don't forget to add a " " for a space.
print("Firstname" + " " + "Lastname")

# %% [markdown]
# ## 📣 Task 2: The Echo Machine
# Python can repeat words using the * (multiplication) symbol. Your Goal: Make Python say the word "Echo!" 10 times in a row.

# %%
# Type your code to repeat "Echo! " ten times:

# %% [markdown]
# ## 🍦 Task 3: Single vs. Double Quotes
# Python accepts both 'single quotes' and "double quotes". Your Goal: Write a code cell that prints your favorite ice cream flavor using single quotes, and then another line that prints your favorite hobby using double quotes.

# %%
# Use single quotes for ice cream:

# Use double quotes for your hobby:

# %% [markdown]
# ## 🚧 Task 4: The Number Trap
# Remember, if you put a number inside quotes like "5", Python thinks it is a piece of text (a string), not a number! You cannot add a regular number to a string. Your Goal: Fix the code below so it doesn't crash. You need to make sure both items are strings.

# %%
# FIX THIS CODE:
print("I have " + 3 + " pets")

# %% [markdown]
# ## 🕵️ Task 5: Character Count Challenge
# Strings are made of "characters," which include letters, spaces, and even symbols. Your Goal: Look at the string below. Using what you learned about repetition (*), make a "fence" of 20 hashtags (#) to go across the screen.

# %%
# Make a fence of 20 hashtags:
