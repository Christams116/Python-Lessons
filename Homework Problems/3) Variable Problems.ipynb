# %% [markdown]
# # 📦 Python Homework: The Power of Variables
# Instructions: Copy and paste these cells into your notebook. Variables help us store information so we can use it later!
#
# ## 🏷️ Task 1: Labeling Your Box
# A variable is a name that holds information. Your Goal: Create a variable named **my_favorite_number** and give it a value of any whole number you like. Then, use **print()** to show it!

# %%
# Create your variable below:
my_favorite_number = 

# Now print it:
print(my_favorite_number)

# %% [markdown]
# ## 🧮 Task 2: Math with Variables
# If a variable holds a number, Python can do math with it. Your Goal: Create a variable called cookies and set it to 5. Create another variable called friends and set it to 3. Multiply them together to see how many cookies you need!

# %%
# Create your variables:
cookies = 5
friends = 3

# Multiply them together (use the * symbol):
total = 
print(total)

# %% [markdown]
# ## 🧶 Task 3: Word Tag-Team
# You can join string variables together using the + symbol. This is called concatenation. Your Goal: Create two variables: part1 should be "Super" and part2 should be "Hero". Join them together to make one word.

# %%
part1 = "Super"
part2 = "Hero"

# Join them together in a new variable called team:
team = 
print(team)

# %% [markdown]
# ## 🛠️ Task 4: The Fix-It Challenge
# Python gets confused when you try to add a string variable to a number variable. Your Goal: The code below is broken! Use the str() command to turn the number into a string so it can be printed with the words.

# %%
# FIX THIS CODE:
points = 50
print("You scored " + points + " points!")

# Hint: Change 'points' to 'str(points)' inside the print!

# %% [markdown]
# ## 🚀 Task 5: The "Acts Like" Test
# Remember: A variable acts as what it represents. Your Goal: 1. Create a variable called test and set it to "10" (with quotes). 2. Create another variable called result that is test * 3. 3. Print result. Did it give you 30 or 101010? Why?

# %%
# Try it out here:
test = "10"
result = test * 3
print(result)
