# %% [markdown]
# # 🚦 Python Homework: Decision Time!
# Instructions: Copy and paste these cells into your notebook. Your goal is to fill in the missing code to make the programs work!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 🏰 Task 1: The Secret Clubhouse
# To get into the secret clubhouse, you need to know the secret word: "Friend". Your Goal: Ask the user for the password. If they type "Friend", print "Welcome inside! 🗝️". Otherwise, print "Sorry, only club members allowed! 🛑"

# %%
# 1. Ask the user for the secret word:


# 2. Write an if/else statement to check if they got it right:
# Hint: Use == to compare strings!

# %% [markdown]
# ## 🧥 Task 2: The Weather Reporter
# Let's help someone decide what to wear based on a Boolean value. Your Goal: Create a variable called is_raining.
#
#     Set it to True or False.
#
#     Write an if statement that prints "Bring an umbrella! ☔" if it is raining.
#
#     Write an else statement that prints "Enjoy the sunshine! ☀️" if it is not.

# %%
# 1. Set the variable (use True or False):
is_raining = 

# 2. Write your if/else logic below:
# Hint: Don't forget the colon (:) at the end of the if and else lines!

# %% [markdown]
# ## 🍕 Task 3: The Pizza Party Math
# You are having a pizza party! You have 10 slices of pizza. Your Goal: Ask the user how many slices they want to eat.
#
#     If the number they type is less than or equal to 10, print "Coming right up! 🍕".
#
#     If they ask for more than 10, print "Oops, we don't have enough pizza! 😵".

# %%
# 1. Get the number from the user (Don't forget to use int()!):


# 2. Check if the number is less than or equal to 10 (use <=):

# %% [markdown]
# ## 🎮 Task 4: High Score Hero
# You want to see if a player beat the "All-Time High Score" of 100 points. Your Goal: Ask the player for their score.
#
#     If their score is greater than 100, print "NEW RECORD! 🏆".
#
#     Otherwise, print "Good try! Can you beat 100 next time? 🕹️".

# %%
# 1. Ask for the player's score and convert it to an integer:


# 2. Use a comparison operator ( > ) to check the score:

# %% [markdown]
# ## 🥛 Task 5: The Cereal Bowl Mystery
# In Python, we use != to mean "Not Equal To." Your Goal: Ask the user "Is the milk carton empty? (Yes/No)".
#
#     If their answer is NOT EQUAL TO "Yes", print "Time for breakfast! 🥣".
#
#     Otherwise, print "We need to go to the store! 🛒".

# %%
# 1. Ask the question:
status = input("Is the milk carton empty? ")

# 2. Use the != symbol to see if the answer is NOT "Yes":
if status != "Yes":
    print("Time for breakfast! 🥣")
else:
    print("We need to go to the store! 🛒")
