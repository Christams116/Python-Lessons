# %% [markdown]
# # ✅ Practice Problems: input()
# ## ⭐ Problem 1: Name + Hobby
#
# Create inputs that ask for the user’s:
#
# **ame**
#
# **obby**
#
# Then print the result exactly like this:
#
# **"Your name is " + name + " and your favorite hobby is " + hobby**
#
# 💡 **Hint 1:** Use input() to ask questions
#
# 💡 **Hint 2:** Store answers in variables
#
# Your code here:

# %%
#Code Here

# %% [markdown]
# ## 🐶 Problem 2: Dog Years (Two Lines)
#
# Create an input that saves the user’s age.
#
# Then print the results in two lines:
#
# **Your age in dog years:**
# **dog_years**
#
# 💡 **Hint 1:** The input will be a string, so you must convert it using int()
#
# 💡 **Hint 2:** dog_years = age * 7
#
# Your code here:

# %%
#Code Here

# %% [markdown]
# ## 🐕 Problem 3: Dog Years (One Line)
#
# Create an input that saves the user’s age.
#
# Then print the result in one line like this:
#
# **"Your age in dog years: " + dog_years**
#
# 💡 **Hint 1:** You can’t add a string + number, so use **str()**
#
# 💡 **Hint 2:** Use str(dog_years) inside your print
#
# Your code here:

# %%
#Code Here
