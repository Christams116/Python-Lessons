# %% [markdown]
# # Pratice Problems!

# %% [markdown]
# ## ⭐ Problem 1: “About Me” Sentence (No Variables)
#
# Instead of using variables, you will build the sentence by adding strings together like this:
#
# 💡 Hint: "My name is " + "Chris" ==> "My name is Chris"
#
# ✅ Your task:
#
# Use print() to display this sentence using only strings:
#
# "My name is Chris I am in 5th grade, and my favorite hobby is basketball"
#
# 💡 Hint 1: Put spaces inside your strings like " " so the words don’t smash together.
# 💡 Hint 2: Use + to join strings.
#
# Your code here:

# %% [markdown]
# ### Code Here

# %%
# Code Here

# %% [markdown]
# ## 🌲 Problem 2: Print a Tree
#
# Use print() statements to make this shape:

# %% [markdown]
# &emsp; &ensp;  ^
#
# &ensp; &nbsp;  ^^^
#
# &ensp; ^^^^^
#
# ^^^^^^^

# %%
# Hint
print("   ^")
print("  ^^^")

# %% [markdown]
# ### Code Here:

# %%
# Code Here

# %% [markdown]
# ## 🐶 Problem 3: Dog Years Calculator
#
# Make a variable called age, then print:
#
# My age in dog years is:
#
# Then print the dog-years number:
#
# #### **age∗7**
#
# 💡 Hint 1: Multiply numbers using *
#
# 💡 Hint 2: You can use two print statements (one for the message, one for the number)

# %% [markdown]
# ### Code Here

# %%
# Code Here
