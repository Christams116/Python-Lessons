# %% [markdown]
# # 🚦 In-Class Practice: Logic & Decisions
# Instructions: Copy and paste these cells. Follow the directions to help Python make the right choices!
#
# ## ⭐ Problem 1: The Magic Equal Sign
# Remember: = is for giving a value, but == is for asking if two things are the same. ✅ Your task: Create a variable called guess and set it to a number. Then, write an if statement to check if the guess is equal to 7. If it is, print "You found the magic number!"

# %%
# 1. Create the variable 'guess' and set it to a number:


# 2. Write the if statement below:
# Hint: Use == and don't forget the : at the end!

# %% [markdown]
# ## 🍦 Problem 2: The Ice Cream Shop
# We can use else to give a "backup" plan if our first choice isn't true. ✅ Your task: Ask the user "Do you like chocolate? (Type Yes or No)". Store their answer in a variable. Use an if/else block to print "Me too!" if they say Yes, and "Vanilla is good too!" if they say False.

# %%
# 1. Ask the question and store it in a variable:
answer = input("Do you like chocolate? (Yes/No): ")

# 2. Write your if/else decision here:

# %% [markdown]
# ## 🎢 Problem 3: The Roller Coaster Guard
# To ride the "Mega-Loop," you must be at least 48 inches tall. ✅ Your task:
#
# Use input() to ask for the user's height.
#
# Convert the input to an int (number).
#
# Use > or >= to check if they are tall enough.
#
# Use else to tell them how many more inches they need to grow!

# %%
# 1. Get the height and convert it to an int():


# 2. Use if/else to check if height is greater than or equal to 48:
