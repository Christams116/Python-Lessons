# %% [markdown]
# # 🧵 Strings in Python (Words & Text)
#
# A string is text written inside quotes:
#
# ✅ Double quotes:
#
# "Hello"
#
# ✅ Single quotes:
#
# 'Hello'
#
# Strings are made of characters, like letters and symbols.

# %% [markdown]
# ✅ String Addition (Concatenation)
#
# You can combine strings using +

# %% [markdown]
# Example:

# %%
print("Hello " + "World")

# %% [markdown]
# ✅ String Repetition
#
# You can repeat strings using *

# %% [markdown]
# Example:

# %%
print("Repeat" * 5)

# %% [markdown]
# # ⚠️ IMPORTANT: You can’t add a String + Number
#
# This will cause an error ❌:

# %%
print("My Age is " + 22)

# %% [markdown]
# But this is okay ✅ (because both are strings):

# %%
print("My Age is " + "22")
