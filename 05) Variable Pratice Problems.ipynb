# %% [markdown]
# # ✅ Practice Problem Worksheet: Variables
# ## ⭐ Problem 1: About Me Variables
#
# Define the following variables:
#
# **name**
#
# **grade**
#
# **hobby**
#
# Then print the sentence in this exact format:
#
# "My name is " + name + " I am in " + grade + " grade, and my favorite hobby is " + hobby
#
# 💡 **Hint 1:** name and hobby should be strings, like "Chris"
#
# 💡 **Hint 2:** grade can be a string too, like "5th" or "3"
#
# Your code here:

# %%
# Code Here

# %% [markdown]
# ## 🐶 Problem 2: Dog Years
#
# Define a variable called age, then create another variable called dog_age using:
#
# **dog_age=age∗7**
#
# Then print it in this format:
#
# **My age in dog years is:
#
# {dog_age}**
#
# 💡 **Hint 1:** Multiply using *
#
# 💡 **Hint 2:** Use two print statements (one for the sentence, one for the number)
#
# Your code here:

# %%
# Code Here
