# %% [markdown]
# # 🧩 In-Class Practice: Type Conversion Mastery
# Instructions: Copy each cell into your notebook. Work together to solve these puzzles!
#
# ## ⭐ Problem 1: The Birthday Surprise
# You want to tell the computer how old you will be next year. But remember, you can't add a string and a number together without a conversion!
#
# ### ✅ Your task:
#
# Create a variable called current_age and set it to your age (as an integer).
#
# Create a variable called next_year that adds 1 to current_age.
#
# Use print() to display: "Next year, I will be " + the string version of next_year.
#
# 💡 Hint: Use str() to turn your number into a string for the final print!

# %%
# Your code here:

# %% [markdown]
# ## 🎨 Problem 2: Art Repeater
# In Python, you can "multiply" a string to repeat it. We can use int() to turn a user's answer into a number for this trick!
#
# ### ✅ Your task:
#
# Ask the user for a shape or emoji (like "*" or "@") using input().
#
# Ask the user for a number using input().
#
# Convert that number string into a real integer using int().
#
# Print the shape multiplied by that number!

# %%
# 1. Ask for a shape:

# 2. Ask for a number:

# 3. Convert and print:

# %% [markdown]
# ## 🛍️ Problem 3: The Candy Store
# Imagine a piece of candy costs $1.50. You want to find the total price for a bag of candy.
#
# ### ✅ Your task:
#
# Create a variable price set to 1.5 (a float).
#
# Use input() to ask the user "How many pieces of candy do you want?".
#
# Convert that input to an integer.
#
# Multiply the price by the number of pieces and print the total.
#
# 💡 Hint: total = price * int(amount_from_user)

# %%
# Your code here:

# %% [markdown]
# ## 🚀 Problem 4: The Giant Sentence
# Combine everything! Ask for a name and a year of birth. Calculate how old they will be in the year 2050.
#
# ### ✅ Your task:
#
# Get the name (string).
#
# Get the birth_year and convert it to an int.
#
# Subtract birth_year from 2050 to get the future age.
#
# Print: "Hello [name], in the year 2050 you will be [future_age] years old!"

# %%
# Your code here:
